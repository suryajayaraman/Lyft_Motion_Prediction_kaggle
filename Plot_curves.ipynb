# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_path = '/home/wabco/Downloads/sdxc/Git repos/Lyft_Motion_Prediction_kaggle/submissions/LSTM_Baseline/'
file_name = 'LSTM_baseline_R34_pvt_10_224_nll_multimode_TRAIN_LOSSES_156k-340k.csv'
df = pd.read_csv(data_path + file_name)

# %%
df.head()
# Out:
#    iteration  losses_train
# 0       9751    199.293274
# 1       9752    401.640442
# 2       9753    201.808273
# 3       9754    281.696777
# 4       9755    195.898621

# %%
plot_df = df.iloc[::10, :]

# %%
plt.figure(figsize=(10,10))
plt.plot(plot_df['iteration'].values * 16, plot_df['losses_train'].values)
plt.savefig('LSTM_baseline_train_losses_156k-340k.png')

# %%
file_name = 'LSTM_baseline_R34_pvt_10_224_nll_multimode_340k.csv'
df = pd.read_csv(data_path + file_name)

# %%
df.head()
# Out:
#    Instance  iterations  metrics (avg)  elapsed_time (mins)  \
# 0         1           0    9114.376953             0.121932
# 1         1         250    1030.141492             7.367941
# 2         1         500     698.777960            14.722123
# 3         1         750     588.578953            22.211889
# 4         1        1000     528.523477            29.821913
#
#    Total elapsed time
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
plot_df = df.iloc[::10, :]

# %%
plt.figure(figsize=(10,10))
plt.plot(plot_df['iterations'].values[1:] * 16, plot_df['metrics (avg)'].values[1:])
plt.savefig('LSTM_baseline_train_losses_0-340k.png')
